# %% [markdown]
# # K-Means

# %%
import pandas as pd
from numpy import array
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.metrics import accuracy_score

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture

from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import cross_val_score
# %matplotlib inline

from sklearn.model_selection import learning_curve

from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt

import itertools

from scipy import linalg
import matplotlib as mpl
from sklearn import mixture

from sknn import ae, mlp
from sklearn.decomposition import PCA
from sklearn import random_projection


data = pd.read_csv("adult.data.csv")
train_columns = data.columns.values.tolist()[:-1]
last_column = data.columns.values.tolist()[-1]
category = []
for el in train_columns:
    if type(data[el].tolist()[0]) == str:
        category.append(el)

new_data = pd.get_dummies(data, columns=category)
onehot_train_columns = new_data.columns.values.tolist()
onehot_train_columns.remove(data.columns.values.tolist()[-1])

X = new_data[onehot_train_columns]
X_old = X
scaling = StandardScaler().fit(X)
X = scaling.transform(X)
y = new_data[last_column]


true_labels = pd.get_dummies(y, last_column)
true_labels = true_labels[true_labels.columns.values.tolist()[-1]].tolist()

def draw_GM(X, Y_, means, covariances, index, title, size=2, xlim=None, ylim=None, draw_ellipse=True):
    _, splot = plt.subplots(1, sharex=True)
    for i, (mean, covar, color) in enumerate(zip(
            means, covariances, color_iter)):
        v, w = linalg.eigh(covar)
        v = 2. * np.sqrt(2.) * np.sqrt(v)
        u = w[0] / linalg.norm(w[0])
        # as the DP will not use every component it has access to
        # unless it needs it, we shouldn't plot the redundant
        # components.
        if not np.any(Y_ == i):
            continue
        plt.scatter(X[Y_ == i, 0], X[Y_ == i, 1], s=size,color=color)

        # Plot an ellipse to show the Gaussian component
        angle = np.arctan(u[1] / u[0])
        angle = 180. * angle / np.pi  # convert to degrees
        ell = mpl.patches.Ellipse(mean, v[0], v[1], 180. + angle, color=color)
        ell.set_clip_box(splot.bbox)
        ell.set_alpha(0.5)
        if draw_ellipse:
            splot.add_artist(ell)

    if xlim:
        plt.xlim(xlim)
    if ylim:
        plt.ylim(ylim)
    plt.title(title)
    plt.show()

def draw_kmeans(X, labels, centroids, clusters, title, size=5, xlim=None, ylim=None):
    _, ax1 = plt.subplots(1, sharex=True)
    for i in range(clusters):
        # select only data observations with cluster label == i
        ds = X[np.where(labels==i)]
        # plot the data observations
        ax1.scatter(ds[:,0],ds[:,1],s=size)
        # plot the centroids
        lines = plt.plot(centroids[i,0],centroids[i,1],'kx')
        # make the centroid x's bigger
        plt.setp(lines,ms=15.0)
        plt.setp(lines,mew=2.0)
    if xlim:
        plt.xlim(xlim)
    if ylim:
        plt.ylim(ylim)
    plt.title(title)
    plt.show()

# %%
def kmeans_cluster(X, true_output):
    param = range(2, 50)
    scores = []
    inertia = []
    for el in param:
        KM = KMeans(n_clusters=el, n_jobs=-1).fit(X)
        label = KM.labels_
        inertia.append(KM.inertia_)
        scores.append(metrics.adjusted_rand_score(true_output, label))
    
    return param, scores, inertia

def kmeans_iter(X, true_output, clusters):
    param = range(5, 100)
    inertia = []
    for el in param:
        KM = KMeans(n_clusters=clusters, max_iter=el, n_jobs=-1, random_state=1).fit(X)
        label = KM.labels_
        inertia.append(KM.inertia_)
    return param, scores


kmeans_cluster_x, kmeans_cluster_scores, kmeans_cluster_inertia = kmeans_cluster(X, true_labels)
clusters = kmeans_cluster_x[kmeans_cluster_scores.index(max(kmeans_cluster_scores))]
print "done"
kmeans_iter_x, kmeans_iter_inertia = kmeans_iter(X, true_labels, clusters)
# Out:
# done

# %%
print clusters
f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(kmeans_cluster_x, kmeans_cluster_scores)
plt.xlabel("Number of clusters")
plt.ylabel("Adjusted rand score")
plt.title("KMeans cluster scoring")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(kmeans_cluster_x, kmeans_cluster_inertia)
plt.xlabel("Number of clusters")
plt.ylabel("Inertia / Sum Squared Error")
plt.title("KMeans cluster SSE")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(kmeans_iter_x, kmeans_iter_inertia)
plt.xlabel("Max iterations")
plt.ylabel("Inertia / Sum Squared Error")
plt.title("Max iteration SSE, same random seed")
plt.legend()

KM = KMeans(n_clusters=2, n_jobs=-1).fit(X)
draw_kmeans(X, KM.labels_, KM.cluster_centers_, 2, "KMeans output 2D visualization", 0.2)
draw_kmeans(X, np.array(true_labels), KM.cluster_centers_, 2, "KMeans real 2D visualization", 0.2)
# Out:
# 2

# %% [markdown]
# # Expectation Maximization

# %%
def GM_clusters(X, true_output):
    param = range(2, 50)
    likelihood = []
    scores = []
    for el in param:
        GM = GaussianMixture(n_components=el, random_state=1).fit(X)
        label = GM.predict(X)
        
        likelihood.append(GM.score(X))
        scores.append(metrics.adjusted_rand_score(true_output, label))
    return param, scores, likelihood

def GM_iter(X, true_output, components):
    param = range(1, 100)
    likelihood = []
    for el in param:
        GM = GaussianMixture(n_components=components, max_iter=el, random_state=1).fit(X)
        label = GM.predict(X)

        likelihood.append(GM.score(X))

    return param, likelihood


GM_cluster_x, GM_cluster_scores, GM_cluster_likelihood = GM_clusters(X, true_labels)
components = GM_cluster_x[GM_cluster_scores.index(max(GM_cluster_scores))]
print "Done"
GM_iter_x, GM_iter_likelihood = GM_iter(X, true_labels, components)
# Out:
# Done
# C:\Users\DongSon\Anaconda2\lib\site-packages\sklearn\mixture\base.py:237: ConvergenceWarning: Initialization 1 did not converged. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   % (init + 1), ConvergenceWarning)

# %%
print components
f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(GM_cluster_x, GM_cluster_scores)
plt.xlabel("Number of components")
plt.ylabel("Adjusted rand score")
plt.title("EM components scoring")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(GM_cluster_x, GM_cluster_likelihood)
plt.xlabel("Number of components")
plt.ylabel("Avg log likelihood")
plt.title("EM components log likelihood")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(GM_iter_x, GM_iter_likelihood)
plt.xlabel("Max iterations")
plt.ylabel("Avg log likelihood")
plt.title("EM max itereration scoring, same random seed")
plt.legend()

GM = GaussianMixture(n_components=2).fit(X)
draw_GM(X, GM.predict(X), GM.means_, GM.covariances_, 1, "EM output 2D visualization", 0.5)
draw_GM(X, np.array(true_labels), GM.means_, GM.covariances_, 1, "EM real 2D visualization", 0.5)
# Out:
# 2

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

p = PCA(n_components="mle", svd_solver="full").fit(X)

var = p.explained_variance_ratio_
cumsum_var = p.explained_variance_ratio_.cumsum()

f, ax1 = plt.subplots(1, sharex=True)
ax1.scatter(range(len(var)), var, s=7)
plt.xlabel("Principal component number")
plt.ylabel("% Variance")
plt.title("% Variance of each principal component")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(range(len(cumsum_var)), cumsum_var)
plt.xlabel("# Principal components used")
plt.ylabel("% Cumulative variance")
plt.title("% Cumulative variance of best principal components")
plt.legend()

# %%
from sklearn.decomposition import PCA
def PCA_kmeans(X, true_output):
    param = [i * 0.05 for i in range(1, 21)]
    scores = []
    components = []
    for el in param:
        p = PCA(n_components=el if el != 1.0 else "mle", svd_solver="full", random_state=1).fit(X)
        X_new = p.transform(X)
        components.append(p.n_components_)
        
        KM = KMeans(n_clusters=2, n_jobs=-1, random_state=1).fit(X_new)
        label = KM.labels_
        scores.append(metrics.adjusted_rand_score(true_output, label))

    return scores, components

def PCA_GM(X, true_output):
    param = [i * 0.05 for i in range(1, 21)]
    scores = []
    components = []
    for el in param:
        p = PCA(n_components=el if el != 1.0 else "mle", svd_solver="full", random_state=1).fit(X)
        X_new = p.transform(X)
        components.append(p.n_components_)

        GM = GaussianMixture(n_components=2, random_state=1).fit(X_new)
        label = GM.predict(X_new)
        scores.append(metrics.adjusted_rand_score(true_output, label))

    return scores, components



PCA_kmeans_scores, PCA_kmeans_clusters = PCA_kmeans(X, true_labels)
print "done"
PCA_GM_scores, PCA_GM_components = PCA_GM(X, true_labels)
# Out:
# done

# %%
print PCA_kmeans_scores
print PCA_kmeans_clusters
f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(PCA_kmeans_clusters, PCA_kmeans_scores)
plt.xlabel("PCA components kept")
plt.ylabel("Adjusted rand score")
plt.title("PCA + KMeans scoring")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(PCA_GM_components, PCA_GM_scores)
plt.xlabel("PCA components kept")
plt.ylabel("Adjusted rand score")
plt.title("PCA + EM scoring")
plt.legend()


p = PCA(n_components=0.2, svd_solver="full", random_state=1).fit(X)
X_pca = p.transform(X)


GM = GaussianMixture(n_components=2).fit(X_pca)
draw_GM(X_pca, GM.predict(X_pca), GM.means_, GM.covariances_, 1, "PCA + EM output 2D visualization", 0.5)
draw_GM(X_pca, np.array(true_labels), GM.means_, GM.covariances_, 1, "PCA + EM true 2D visualization", 0.5)

KM = KMeans(n_clusters=2, n_jobs=-1).fit(X_pca)
draw_kmeans(X_pca, KM.labels_, KM.cluster_centers_, 2, "PCA + KMeans output 2D visualization", 0.2)
draw_kmeans(X_pca, np.array(true_labels), KM.cluster_centers_, 2, "PCA + KMeans real 2D visualization", 0.2)
# Out:
# [0.17511110953090742, 0.17569865226595102, 0.17630783866387958, 0.18697181042147204, 0.18318062008611979, 0.18296167252165524, 0.18229211875255227, 0.1822032938261528, 0.18233550423507464, 0.18227690764953508, 0.18225790082080739, 0.18253198343294544, 0.18267941116620959, 0.18272856676234089, 0.18237661799407634, 0.18210257788251413, 0.18208347180929899, 0.18161563183215299, 0.18164532928466803, 0.180091499844558]
# [2, 4, 6, 9, 13, 18, 23, 27, 33, 38, 43, 48, 54, 59, 65, 70, 76, 82, 88, 107]

# %% [markdown]
# # Randomized Projections

# %%
from sklearn import random_projection

def GRP_kmeans(X, true_output):
    param = range(1, int(len(X[0]) * 0.8), 5)
    scores = []
    components = []
    for el in param:
        transformer = random_projection.GaussianRandomProjection(n_components=el).fit(X)
        X_new = transformer.transform(X)
        
        KM = KMeans(n_clusters=2, n_jobs=-1).fit(X_new)
        label = KM.labels_
        scores.append(metrics.adjusted_rand_score(true_output, label))

    return scores, param

def GRP_GM(X, true_output):
    param = range(1, int(len(X[0]) * 0.8), 5)
    scores = []
    components = []
    for el in param:
        transformer = random_projection.GaussianRandomProjection(n_components=el).fit(X)
        X_new = transformer.transform(X)

        GM = GaussianMixture(n_components=2).fit(X_new)
        
        label = GM.predict(X_new)
        scores.append(metrics.adjusted_rand_score(true_output, label))

    return scores, param

GRP_kmeans_scores_arr = []; GRP_kmeans_components_arr = []
GRP_GM_scores_arr = []; GRP_GM_components_arr = []

for i in range(5):
    GRP_kmeans_scores, GRP_kmeans_components = GRP_kmeans(X, true_labels)
    GRP_GM_scores, GRP_GM_components = GRP_GM(X, true_labels)
    
    GRP_kmeans_scores_arr.append(GRP_kmeans_scores)
    GRP_kmeans_components_arr.append(GRP_kmeans_components)
    GRP_GM_scores_arr.append(GRP_GM_scores)
    GRP_GM_components_arr.append(GRP_GM_components)

# %%
f, ax1 = plt.subplots(1, sharex=True)
for i in range(5):
    ax1.plot(GRP_kmeans_components_arr[i], GRP_kmeans_scores_arr[i])
plt.xlabel("Target dimensionality")
plt.ylabel("Adjusted rand score")
plt.title("Random Projections + KMeans scoring")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
for i in range(5):
    ax1.plot(GRP_GM_components_arr[i], GRP_GM_scores_arr[i])
plt.xlabel("Target dimensionality")
plt.ylabel("Adjusted rand score")
plt.title("Random Projections + EM scoring")
plt.legend()

transformer = random_projection.GaussianRandomProjection(n_components=60).fit(X)
X_rp = transformer.transform(X)
RP_train_sizes, RP_train_score, RP_test_score = learning_curve_NN(X_rp, y, 25, 2)

xlim = (-6, 6)
ylim = (-6, 6)
GM = GaussianMixture(n_components=2).fit(X_rp)
draw_GM(X_rp, GM.predict(X_rp), GM.means_, GM.covariances_, 1, "RP + EM output 2D visualization", 0.5, xlim, ylim)
draw_GM(X_rp, np.array(true_labels), GM.means_, GM.covariances_, 1, "RP + EM true 2D visualization", 0.5, xlim, ylim)

KM = KMeans(n_clusters=2, n_jobs=-1).fit(X_rp)
draw_kmeans(X_rp, KM.labels_, KM.cluster_centers_, 2, "RP + KMeans output 2D visualization", 0.2, xlim, ylim)
draw_kmeans(X_rp, np.array(true_labels), KM.cluster_centers_, 2, "RP + KMeans real 2D visualization", 0.2, xlim, ylim)

# %%
from sknn import ae, mlp
def AE_run(X, true_output, out):
    size = len(X[0])
    param = range(1, int(size * 0.5), 10)
    kmeans_scores = []
    GM_scores = []
    for el in param:
    
        AELayers = [
            ae.Layer("Sigmoid", units=size),
            ae.Layer("Sigmoid", units=out),
            ae.Layer("Sigmoid", units=el)
        ]
        myae = ae.AutoEncoder(layers=AELayers)
        myae.fit(X)
        X_new = myae.transform(X)


        KM = KMeans(n_clusters=2, n_jobs=-1).fit(X_new)
        KM_label = KM.labels_
        kmeans_scores.append(metrics.adjusted_rand_score(true_output, KM_label))
    
        GM = GaussianMixture(n_components=2).fit(X_new)
        GM_label = GM.predict(X_new)
        GM_scores.append(metrics.adjusted_rand_score(true_output, GM_label))
        print el
    
    return param, kmeans_scores, GM_scores

AE_x, AE_kmeans_scores, AE_GM_scores = AE_run(X, true_labels, 2)
# Out:
# 1
# 11
# 21
# 31
# 41
# 51

# %%
f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(AE_x, AE_kmeans_scores)
plt.xlabel("Target dimensionality")
plt.ylabel("Adjusted rand score")
plt.title("AutoEncoders + KMeans scoring")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(AE_x, AE_GM_scores)
plt.xlabel("Target dimensionality")
plt.ylabel("Adjusted rand score")
plt.title("AutoEncoders + EM scoring")
plt.legend()

layers = [
    ae.Layer("Sigmoid", units=len(X[0])),
    ae.Layer("Sigmoid", units=2),
    ae.Layer("Sigmoid", units=30)
]

myae = ae.AutoEncoder(layers=layers)
myae.fit(X)
X_ae = myae.transform(X)

xlim = (0.6335, 0.6343)
ylim = (0.6330, 0.6340)
xlim = None
ylim = None
GM = GaussianMixture(n_components=2).fit(X_ae)
print sum(GM.predict(X_ae)), len(GM.predict(X_ae))
draw_GM(X_ae, GM.predict(X_ae), GM.means_, GM.covariances_, 1, "AE + EM output 2D visualization", 0.5, xlim, ylim, False)
draw_GM(X_ae, np.array(true_labels), GM.means_, GM.covariances_, 1, "AE + EM true 2D visualization", 0.5, xlim, ylim, False)

KM = KMeans(n_clusters=2, n_jobs=-1).fit(X_ae)
draw_kmeans(X_ae, KM.labels_, KM.cluster_centers_, 2, "AE + KMeans output 2D visualization", 0.2, xlim, ylim)
draw_kmeans(X_ae, np.array(true_labels), KM.cluster_centers_, 2, "AE + KMeans real 2D visualization", 0.2, xlim, ylim)
# Out:
# 10133 32561

# %% [markdown]
# # Neural Net Runs

# %%
def learning_curve_NN(X, y, nodes, layers):

    train_size_rate = [round(0.1 * el, 2) for el in range(1, 11, 1)]
    NN = MLPClassifier(hidden_layer_sizes=(nodes,) * layers, max_iter=2000)

    a, train_scores, test_scores = learning_curve(NN, X, y, train_sizes=train_size_rate, n_jobs=-1)

    return a, train_scores, test_scores

# %%
p = PCA(n_components=0.2, svd_solver="full", random_state=1).fit(X)
X_pca = p.transform(X)
PCA_train_sizes, PCA_train_score, PCA_test_score = learning_curve_NN(X_pca, y, 25, 2)

transformer = random_projection.GaussianRandomProjection(n_components=60).fit(X)
X_rp = transformer.transform(X)
RP_train_sizes, RP_train_score, RP_test_score = learning_curve_NN(X_rp, y, 25, 2)

layers = [
    ae.Layer("Sigmoid", units=len(X[0])),
    ae.Layer("Sigmoid", units=2),
    ae.Layer("Sigmoid", units=30)
]
myae = ae.AutoEncoder(layers=layers)
myae.fit(X / np.max(X))
X_ae = myae.transform(X / np.max(X))
AE_train_sizes, AE_train_score, AE_test_score = learning_curve_NN(X_ae, y, 25, 2)

# %%
f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(PCA_train_sizes, np.mean(PCA_train_score, axis=1), "r", label="training") #red
ax1.plot(PCA_train_sizes, np.mean(PCA_test_score, axis=1), "g", label="testing") #green

plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("Principal Component Analysis learning curve")
plt.legend()


f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(RP_train_sizes, np.mean(RP_train_score, axis=1), "r", label="training") #red
ax1.plot(RP_train_sizes, np.mean(RP_test_score, axis=1), "g", label="testing") #green
plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("Randomized Projections learning curve")
plt.legend()


f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(AE_train_sizes, np.mean(AE_train_score, axis=1), "r", label="training") #red
ax1.plot(AE_train_sizes, np.mean(AE_test_score, axis=1), "g", label="testing") #green
plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("AutoEncoders learning curve")
plt.legend()

# %%
# centers [clusters, features]
# X       [samples,  features]
# out     [samples,  new_features = dist to each cluster]

def dist_kmeans(X):
    KM = KMeans(n_clusters=2, n_jobs=-1).fit(X)
    X_new = []
    for el in X:
        row = []
        for c in KM.cluster_centers_:
            row.append(np.linalg.norm(el - c))
        X_new.append(row)
    return np.array(X_new)

def dist_GM(X):
    GM = GaussianMixture(n_components=2).fit(X)
    X_new = []
    for el in X:
        row = []
        for c in GM.means_:
            row.append(np.linalg.norm(el - c))
        X_new.append(row)
    return np.array(X_new)

kmeans_X = dist_kmeans(X_pca)
GM_X_pca = dist_GM(X_pca)

kmeans_X_rp = dist_kmeans(X_rp)
GM_X_rp = dist_GM(X_rp)

kmeans_X_ae = dist_kmeans(X_ae)
GM_X_ae = dist_GM(X_ae)

# %%
kmeans_X_pca_train_size, kmeans_X_pca_train_score, kmeans_X_pca_test_score = learning_curve_NN(kmeans_X_pca, y, 25, 2)
GM_X_pca_train_size, GM_X_pca_train_score, GM_X_pca_test_score = learning_curve_NN(GM_X_pca, y, 25, 2)
kmeans_X_rp_train_size, kmeans_X_rp_train_score, kmeans_X_rp_test_score = learning_curve_NN(kmeans_X_rp, y, 25, 2)
GM_X_rp_train_size, GM_X_rp_train_score, GM_X_rp_test_score = learning_curve_NN(GM_X_rp, y, 25, 2)
kmeans_X_ae_train_size, kmeans_X_ae_train_score, kmeans_X_ae_test_score = learning_curve_NN(kmeans_X_ae, y, 25, 2)
GM_X_ae_train_size, GM_X_ae_train_score, GM_X_ae_test_score = learning_curve_NN(kmeans_X_ae, y, 8, 2)

# %%
f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(kmeans_X_pca_train_size, np.mean(kmeans_X_pca_train_score, axis=1), "r", label="training") #red
ax1.plot(kmeans_X_pca_train_size, np.mean(kmeans_X_pca_test_score, axis=1), "g", label="testing") #green
plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("PCA learning curve")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(GM_X_pca_train_size, np.mean(GM_X_pca_train_score, axis=1), "r", label="training") #red
ax1.plot(GM_X_pca_train_size, np.mean(GM_X_pca_test_score, axis=1), "g", label="testing") #green
plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("PCA learning curve")
plt.legend()

# %%
f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(kmeans_X_rp_train_size, np.mean(kmeans_X_rp_train_score, axis=1), "r", label="training") #red
ax1.plot(kmeans_X_rp_train_size, np.mean(kmeans_X_rp_test_score, axis=1), "g", label="testing") #green
plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("RP learning curve")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(GM_X_rp_train_size, np.mean(GM_X_rp_train_score, axis=1), "r", label="training") #red
ax1.plot(GM_X_rp_train_size, np.mean(GM_X_rp_test_score, axis=1), "g", label="testing") #green
plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("RP learning curve")
plt.legend()

# %%
f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(kmeans_X_ae_train_size, np.mean(kmeans_X_ae_train_score, axis=1), "r", label="training") #red
ax1.plot(kmeans_X_ae_train_size, np.mean(kmeans_X_ae_test_score, axis=1), "g", label="testing") #green
plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("AutoEncoders learning curve")
plt.legend()

f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(GM_X_ae_train_size, np.mean(GM_X_ae_train_score, axis=1), "r", label="training") #red
ax1.plot(GM_X_ae_train_size, np.mean(GM_X_ae_test_score, axis=1), "g", label="testing") #green
plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("AutoEncoders learning curve")
plt.legend()

# %%
layers = [
    ae.Layer("Sigmoid", units=len(X[0])),
    ae.Layer("Sigmoid", units=len(X[0]) // 2),
    ae.Layer("Sigmoid", units=30)
]
myae = ae.AutoEncoder(layers=layers)
myae.fit(X / np.max(X))
X_ae = myae.transform(X / np.max(X))

xlim = (0.6335, 0.6343)
ylim = (0.6330, 0.6340)
xlim = None
ylim = None
GM = GaussianMixture(n_components=2).fit(X_ae)
print sum(GM.predict(X_ae)), len(GM.predict(X_ae))
draw_GM(X_ae, GM.predict(X_ae), GM.means_, GM.covariances_, 1, "AE + EM output 2D visualization", 0.5, xlim, ylim, False)
draw_GM(X_ae, np.array(true_labels), GM.means_, GM.covariances_, 1, "AE + EM true 2D visualization", 0.5, xlim, ylim, False)

AE_train_sizes, AE_train_score, AE_test_score = learning_curve_NN(X_ae, y, 25, 2)


f, ax1 = plt.subplots(1, sharex=True)
ax1.plot(AE_train_sizes, np.mean(AE_train_score, axis=1), "r", label="training") #red
ax1.plot(AE_train_sizes, np.mean(AE_test_score, axis=1), "g", label="testing") #green
plt.xlabel("training size")
plt.ylabel("accuracy")
plt.title("AutoEncoders learning curve")
plt.legend()
# Out:
# 0 32561

# %%
layers = [
    ae.Layer("Sigmoid", units=len(X[0])),
    ae.Layer("Sigmoid", units=2,
    ae.Layer("Sigmoid", units=30)
]
myae = ae.AutoEncoder(layers=layers)
myae.fit(X / np.max(X))
X_ae = myae.transform(X np.max(X))

xlim = (0.6335, 0.6343)
ylim = (0.6330, 0.6340)
xlim = None
ylim = None
GM = GaussianMixture(n_components=2).fit(X_ae)
print sum(GM.predict(X_ae)), len(GM.predict(X_ae))
draw_GM(X_ae, GM.predict(X_ae), GM.means_, GM.covariances_, 1, "AE + EM output 2D visualization", 0.5, xlim, ylim, False)
draw_GM(X_ae, np.array(true_labels), GM.means_, GM.covariances_, 1, "AE + EM true 2D visualization", 0.5, xlim, ylim, False)

KM = KMeans(n_clusters=2, n_jobs=-1).fit(X_ae)
draw_kmeans(X_ae, KM.labels_, KM.cluster_centers_, 2, "AE + KMeans output 2D visualization", 0.2, xlim, ylim)
draw_kmeans(X_ae, np.array(true_labels), KM.cluster_centers_, 2, "AE + KMeans real 2D visualization", 0.2, xlim, ylim)
# Out:
# 0 32561
